# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig=plt.figure()
labels=["homework","mid_exam","report","final_exam"]
word_size=[200,400,400,600]
explode=[0,0,0,0]
plt.pie(word_size,labels=labels,explode=explode,autopct="%3.1f%%");
